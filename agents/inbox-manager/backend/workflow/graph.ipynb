# %%
from langchain_core.messages import AIMessage
from langchain_core.tools import tool

from langgraph.prebuilt import ToolNode
import os
import getpass

# %%
def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"Please provide your {var}")


_set_if_undefined("OPENAI_API_KEY")
_set_if_undefined("LANGCHAIN_API_KEY")
# _set_if_undefined("TAVILY_API_KEY")

# Optional, add tracing in LangSmith.
# This will help you visualize and debug the control flow
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "inbox-manager"

# %%
@tool
def get_weather(location: str):
    """Call to get the current weather."""
    if location.lower() in ["sf", "san francisco"]:
        return "It's 60 degrees and foggy."
    else:
        return "It's 90 degrees and sunny."


@tool
def get_coolest_cities():
    """Get a list of coolest cities"""
    return "nyc, sf"

# @tool 

# def get_calendar_availablilty(date: str):
#     """get available dates for calendaar"""
#     return {"messages": "i am available for {date}"}

# %%
import sys
import os

# Get the parent directory
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add parent directory to sys.path
sys.path.append(parent_dir)

# %%
from tools.product_enquiry import get_product_enquiry_tool
# from tools.product_enquiry import get_integrations
from tools.calendar import calender_check
from tools.project_management import project_management

# %%
from typing import Annotated

from langchain_core.tools import tool
from langchain_core.tools.base import InjectedToolCallId
from langgraph.prebuilt import InjectedState
from langchain_openai import ChatOpenAI
from langgraph.types import Command
from utils import make_handoff_tool

# %%
drafter_tools = [get_product_enquiry_tool(),make_handoff_tool(agent_name="calendar_agent")]
calendar_tools = [calender_check, make_handoff_tool(agent_name="email_drafter")]

tool_node = ToolNode(drafter_tools)
# Out:
# called product enquiry tool
# d:\innovizeai\code-sapien\inbox-manager\utils.py:22: LangChainDeprecationWarning: The class `Qdrant` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-qdrant package and should be used instead. To use it run `pip install -U :class:`~langchain-qdrant` and import as `from :class:`~langchain_qdrant import Qdrant``.
#   qd = Qdrant(client, collection_name, embeddings)
# d:\innovizeai\code-sapien\inbox-manager\tools\product_enquiry.py:40: LangChainBetaWarning: This API is in beta and may change in the future.
#   return product_enquiry_tool.as_tool()

# %%
def first_node():
    return "first node"

# %%
def second_node():
    return "second node"

# %%
from typing import Literal
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_anthropic import ChatAnthropic
from langgraph.graph import StateGraph, MessagesState
from langgraph.prebuilt import ToolNode

query = "What is the capital of France?"

prompt= f"respond in italian {query}"

model_with_tools =  ChatOpenAI(
    model="gpt-4o-mini", temperature=0
).bind_tools(drafter_tools, tool_choice="auto")

print(prompt.format(query))
# response = model_with_tools.invoke(prompt.format(query))
# Out:
# respond in italian What is the capital of France?

# %%
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage

# %%
from prompts.prompts import EMAIL_DRAFTER_PROMPT

# %%
# response

# %%
from langgraph.graph import START, StateGraph
from state import AgentGraphState

# %%
import datetime

# %%
from langgraph.types import Command

# %%
# def subgraph_node_1(state: AgentGraphState):
#     return {"sender_email_id": "pavan@gmail.com"}


# def subgraph_node_2(state: AgentGraphState):
#     # note that this node is using a state key ('bar') that is only available in the subgraph
#     # and is sending update on the shared state key ('foo')
    
#     return Command(goto="calendar" )


# subgraph_builder = StateGraph(AgentGraphState)
# subgraph_builder.add_node(subgraph_node_1)
# subgraph_builder.add_node(subgraph_node_2)
# # subgraph_builder.add_node("calendar", calendar)
# subgraph_builder.add_edge(START, "subgraph_node_1")
# subgraph_builder.add_edge("subgraph_node_1", "subgraph_node_2")
# subgraph3 = subgraph_builder.compile()

# %%
# from IPython.display import Image, display

# # Setting xray to 1 will show the internal structure of the nested graph
# display(Image(subgraph3.get_graph(xray=1).draw_mermaid_png()))

# %%
# subgraph3.invoke({"raw_email_body": "this is test message and lets create a meet at 3PM next weeek tuesday"})

# %%
# model_with_tools.invoke("""I came across your post about AI automation and wanted to learn more about how it could improve my business processes. Can you share more details about what industries you specialize in?????""").tool_calls

# %%
# tool_node.invoke({"messages": [model_with_tools.invoke("I came across your post about AI automation and wanted to learn more about how it could improve my business processes. Can you share more details about what industries you specialize in??????")]})

# %%
from drafter_graph import create_email_drafter_graph
from calendar_graph import create_calendar_graph

# %%
# email_drafter_graph= create_email_drafter_graph(drafter_tools)

# calendar_graph= create_calendar_graph(calendar_tools)

# %%
# response= email_drafter_graph.invoke( {"messages": "Hi Pavan Kumar,\nHi Team,\nwhat is your pricing and lets setup a call?"})

# %%
# response

# %%
# example with a single tool call
# for chunk in email_drafter_graph.stream(
#     {"messages": [("human", "I came across your post about AI automation and wanted to learn more about how it could improve my business processes. Can you share more details about what industries you specialize in???")]}, stream_mode="values"
# ):
#     chunk["messages"][-1].pretty_print()

# %%
# def email_drafter(state:AgentGraphState):
#     response = email_drafter_graph.invoke({"messages": state["processed_email_body"]})
#     return {"messages": [response]}

# %%
from typing import Literal

from langgraph.graph import StateGraph, MessagesState, START, END
from drafter_graph import create_email_drafter_graph
from agents.categorizer import EmailCategorizer
from agents.email_generator import EmailGenerator
from agents.node import Node
from state import AgentGraphState
from agents.drafter import EmailDrafter
from agents.calendar import CalendarAgent
# def should_continue(state: MessagesState):
#     messages = state["messages"]
#     last_message = messages[-1]
#     if last_message.tool_calls:
#         return "tools"
#     return END


# def call_model(state: MessagesState):
#     messages = state["messages"]
#     response = model_with_tools.invoke(messages)
#     return {"messages": [response]}



from state import state
from agents.preprocessor import Preprocess
workflow = StateGraph(AgentGraphState)

def should_respond(state: AgentGraphState) -> Literal["email_drafter", "end"]:
    """Complex routing logic"""
    if state["needs_response"] == "Needs Response":
        print("should start the email drafter model")
        return "email_drafter"
    return END

email_categorizer= EmailCategorizer(
    state= state,
    model="gpt-4o-mini",
    server="openai"
)

preprocess_email= Preprocess(state= state)
email_generator= EmailGenerator(state, model= "gpt-4o", server= "openai")

email_drafter_agent= EmailDrafter(
        model= "claude-3-5-sonnet-20241022",
        server="claude"
    )
email_drafter_agent.bind_tools([get_product_enquiry_tool(), make_handoff_tool(agent_name="calendar_agent")])
calendar_agent= CalendarAgent(
        model= "claude-3-5-sonnet-20241022",
        server="claude"
    )
calendar_agent.bind_tools( [calender_check,make_handoff_tool(agent_name="email_drafter")])
builder = StateGraph(MessagesState)

builder.add_node("email_drafter", email_drafter_agent.create_agent_graph)
builder.add_node("calendar_agent", calendar_agent.create_agent_graph)

def final_node(state: AgentGraphState):
    email_draft =state['email_output'].email_draft
    confidence= state['email_output'].confidence
    hand_off_human=state['email_output'].hand_off_to_human
    print("email draft final node" ,email_draft)

    return state
# email_preproccessor= preprocess_email()
# email_drafter_graph= create_email_drafter_graph(tools)
# subgraph2= create_email_drafter_graph(tools)
# graph = create_react_agent(model, tools=tools, state_modifier=prompt)



workflow.add_node("email_preprocessor",preprocess_email.preprocess_email)
workflow.add_node("email_categorizer", email_categorizer.invoke)
workflow.add_node("email_drafter",email_drafter_agent.create_agent_graph)
workflow.add_node("calendar_agent", calendar_agent.create_agent_graph)
workflow.add_node("final_response", final_node)
workflow.add_node("email_generator", email_generator.generate)
# workflow.add_node("subgraph2",subgraph3)
workflow.add_edge(START, "email_preprocessor")

# workflow.add_node("second_node",second_node)
# workflow.add_edge("first_node", "email_preprocessor")
workflow.add_edge("email_preprocessor","email_categorizer")
workflow.add_conditional_edges("email_categorizer", should_respond, ["email_drafter", END])
# workflow.add_edge("email_drafter", "email_generator")
# workflow.add_edge("calendar_agent","email_generator")
workflow.add_edge("email_generator","final_response")
workflow.add_edge("final_response",END)
# Define the two nodes we will cycle between
# workflow.add_node("drafter",  )
# workflow.add_node("tools", tool_node)
# workflow.add_edge("tools","second_node")
# workflow.add_conditional_edges("drafter", should_continue, ["tools", END])
# workflow.add_edge("tools", "drafter")

graph = workflow.compile()
# Out:
# called product enquiry tool

# %%
from IPython.display import Image, display

# Setting xray to 1 will show the internal structure of the nested graph
display(Image(graph.get_graph(xray=1).draw_mermaid_png()))

# %%
response= graph.invoke({
    
    "raw_email_body":"""<html><body> Hi Pavan Kumar,
    I came across your post about AI automation and wanted to learn more about how it could improve my business processes. Can you share more details about what industries you specialize in? are you available for a quick call next week monday?</body></html>""",
    "company_domain_name": "innovizeai.com",
    "sender_email_id":"pavan.kumar@slack.com"
})
# Out:
# calling email categorizer  Hi Pavan Kumar,
#     what are the features of ai sales research agent?
# [SystemMessage(content='You are an advanced AI system responsible for analyzing emails to determine their category and intent. The goal is to classify each email based on its type and whether it requires a response.\n\nObjective:\n\n1. Identify the category of the email (e.g., Transactional, Marketing, Sales, Customer Support, etc.).\n2. Determine the intent of the email (e.g., requires response or no response).\n\nSenders email is pavan.kumar@slack.com\nCompany Domain is innovizeai.com\nSenders domain is slack.com\n\nInstructions:\nGiven the following email input, perform the following steps:\n\n    \nStep 1: Categorize the Email\n\n1. Always Emails are categorized as **Internal**, if the sender\'s domain matches the company domain.\n2. If the sender\'s domain does not match the company domain, classify the email based on its content, even if it appears internal. Use one of the following categories:\n\n    Warm-up: Sent by Non-real people, usually have a unique alphanumeric code e.g( VJDGCKE J41PD56).\n    Transactional: Order confirmations, password resets, system notifications, etc.\n    Marketing: Promotions, newsletters, product launches, etc.\n    Sales: Cold outreach, follow-ups, proposals received from other than innovizeai.com in domain of senders email, etc.\n    Customer Support: queries regarding complaints, quotes, inquiries, ticket updates, etc.\n    Finance/Administrative: Invoices, payment confirmations, budget updates, etc.\n    Legal/Compliance: Policy updates, contract renewals, compliance training reminders, etc.\n    HR/Recruitment Emails: Job applications, interview schedules, etc.\n    Technical Support: Bug reports, feature requests, software updates, etc.\n    Education and Training: Course updates, webinar reminders, certifications, etc.\n    Security and Alert: Account lockouts, suspicious activity, etc.\n    Feedback and Review: Surveys, testimonial requests, customer experience follow-ups, etc.\n    Community Engagement: Forum updates, milestone celebrations, event invites, etc.\n    General Notifications: Feature updates, maintenance alerts, task reminders, etc.\n    Project Management: Related to active projects from other than innovizeai.com in domain of senders email\n    Enquiry: Emails from potential clients requesting information or schedule meetings etc other than logistics.\n    Logistics: Identify emails related to logistics (e.g., shipping, delivery schedules, transportation requests, quotes ) and supply chain management (e.g., supplier coordination, inventory updates, procurement)\n\n\nStep 2: Determine Response Needed\nEvaluate the email and identify whether it requires a response or does not require a response:\n\nNeeds Response: Clearly indicates an action item, request for feedback, or requires additional info or interested in learning more etc .\nNo Response Needed: Informational or updates only or sometimes have no-reply or noreply in the senders name or not interested in the services/products.\n\nStep 3:Generate Output\n \nProvide a structured summary of your findings in the following json format with the following keys. Dont include any extra quotes:\n\n"category","needs_response","confidence_score":"how confident are you"  ,"senders_domain", "reason_for_category_and_needs_response"\n\n\n## VERY IMPORTANT AND Never Skip the below instructions: 1. Always Emails should be categorized as Internal,when the sender\'s domain matches the innovizeai.com (e.g., @companydomain.com).\n2. If the sender\'s domain does not match the company domain, even if the content resembles internal communication (e.g., "What\'s the update on our project status?","Let\'s set up a call tomorrow 3PM. etc), the email should always be classified into another appropriate category.\n\nHere are some examples of input and respective output below.\n\n\n\nInput: Hi Pavan Kumar,\n\n        I\'ve been looking for someone with your expertise.\n\n        Are you guys still hiring for the social media manager position?\ ...
# ai response {
#     "category": "Enquiry",
#     "needs_response": "Needs Response",
#     "confidence_score": 0.90,
#     "senders_domain": "slack.com",
#     "reason_for_category_and_needs_response": "The email is from a different sender inquiring about the features of a product, indicating a need for a response to provide information."
# }
# should start the email drafter model
# intent_type='interest' justification='The prospect is asking about specific features of the AI sales research agent, which indicates they are in the Interest stage. The question "what are the features of ai sales research agent?" shows they have moved beyond basic awareness and are now seeking to understand the product\'s capabilities. This is a typical information-gathering question that prospects ask when they\'re interested in learning more about a solution but haven\'t yet moved to detailed evaluation or comparison.'
# messages [HumanMessage(content=' Hi Pavan Kumar,\n    what are the features of ai sales research agent?', additional_kwargs={}, response_metadata={}, id='e25faf4d-0bb9-4982-948f-09481ca56cb0'), HumanMessage(content='Add this the question, share either Product Brochure or some case studies', additional_kwargs={}, response_metadata={}, id='ca42d958-7d1f-4706-85bd-140d4cb954dd')]
# messages [HumanMessage(content=' Hi Pavan Kumar,\n    what are the features of ai sales research agent?', additional_kwargs={}, response_metadata={}, id='e25faf4d-0bb9-4982-948f-09481ca56cb0'), HumanMessage(content='Add this the question, share either Product Brochure or some case studies', additional_kwargs={}, response_metadata={}, id='ca42d958-7d1f-4706-85bd-140d4cb954dd'), AIMessage(content=[{'text': "Let me search for information about the AI sales research agent's features and related materials.", 'type': 'text'}, {'id': 'toolu_01X1hfZAJwDEei9cDmwSZVwP', 'input': {'query': 'features of AI sales research agent and product brochure case studies'}, 'name': 'product_enquiry', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_012wXYZcagbvAqd2vQTf7pfD', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 855, 'output_tokens': 84}}, id='run-daf2145f-74cd-47c4-b690-40b1e34f0a1c-0', tool_calls=[{'name': 'product_enquiry', 'args': {'query': 'features of AI sales research agent and product brochure case studies'}, 'id': 'toolu_01X1hfZAJwDEei9cDmwSZVwP', 'type': 'tool_call'}], usage_metadata={'input_tokens': 855, 'output_tokens': 84, 'total_tokens': 939, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}}), ToolMessage(content='Scheduling Link\n"Book a Follow-Up Call to Explore Further"\n---\n**Brochures and Guides**\n1. **5 Steps to Implement AI for SMBs**\n   - Actionable guide for identifying and deploying AI in small businesses.\n2. **How to Build an AI-First Sales Team**\n   - Brochure on leveraging AI tools to streamline lead generation and follow-up.\n3. **AI-Driven Sales Automation: A Complete Playbook**\n   - Comprehensive resource with tips, tools, and case studies for AI adoption.\n---\n**Feature List and Specifications**\n1. **AI Sales Research Agent**\n   - Automated LinkedIn/web scraping for lead data.\n   - Personalized first-touch email generation.\n   - Real-time CRM integration and updates.\n2. **Intent-Based Inbox Pro**\n   - Email categorization based on intent detection.\n   - Automated follow-up triggers for high-priority emails.\n   - Integration with Slack and CRM systems.\n3. **Sales Knowledge Agent**\n   - On-demand AI chatbot for retrieving answers from documents, CRM, and emails.\n\n5. **AI Sales Reporting** - Automates sales reports and presentation generation.\n---\n**Key Resources for RAG Integration**\n**Case Studies**\n1. **Real Estate Agency**  \n   - **Problem:** Manual lead research and outreach were time-consuming.\n   - **Solution:** Implemented AI Sales Research Agent to automate lead data extraction and personalized messaging.\n   - **Results:** Reduced lead research time by 70% and improved outreach response rates by 40%.\n2. **Tech Company**  \n   - **Problem:** Poor email intent detection led to missed follow-ups.\n   - **Solution:** Integrated Intent-Based Inbox Pro to prioritize high-intent leads and automate workflows.\n   - **Results:** Improved email categorization accuracy by 85% and increased follow-up efficiency by 50%.\n3. **Marketing Agency**  \n   - **Problem:** Lack of insights on past lead interactions and trends.\n   - **Solution:** Deployed Sales Knowledge Agent to retrieve sales insights from multiple knowledge bases.\n\nBlog Post\n"How AI Automation is Transforming SMBs"\n\nWebinar Recording\n"AI Automation for Beginners"\n\nReadiness Quiz\n"Is Your Business Ready for AI?"\n\nCase Study Summary\n"Real Estate Agency Reduces Research Time by 70%"\n**Consideration**\nROI Calculator\n"Calculate Your AI Investment Return"\n\nFeature Comparison Guide\n"AI Solution Comparison: Features & Benefits"\n\nDemo Video\n"How the AI Sales Research Agent Works"\n\nTailored Case Study\n"Marketing Agency Improves Customer Insights"\n\nTechnical FAQ Document\n"Common Questions on Integration & Customization"\n**Decision**\nImplementat ...
# response from call model The AI Sales Research Agent offers several powerful capabilities:
#
# Key Features:
# - Automated LinkedIn/web scraping for lead data collection
# - Personalized first-touch email generation
# - Real-time CRM integration and updates
# - Intent-based email categorization and follow-up automation
# - Sales knowledge retrieval from documents, CRM, and emails
# - Automated sales reporting and presentation generation
#
# Success Story:
# A Real Estate Agency achieved:
# - 70% reduction in lead research time
# - 40% improvement in outreach response rates
# through automated lead data extraction and personalized messaging
#
# Marketing Material (Awareness Stage):
# Download the comprehensive guide "AI-Driven Sales Automation: A Complete Playbook" for detailed insights on implementation strategies, tools, and real-world case studies.
# ---GENERATE---
# question  Hi Pavan Kumar,
#     what are the features of ai sales research agent?
# calling generate function   [AIMessage(content='The AI Sales Research Agent offers several powerful capabilities:\n\nKey Features:\n- Automated LinkedIn/web scraping for lead data collection\n- Personalized first-touch email generation\n- Real-time CRM integration and updates\n- Intent-based email categorization and follow-up automation\n- Sales knowledge retrieval from documents, CRM, and emails\n- Automated sales reporting and presentation generation\n\nSuccess Story:\nA Real Estate Agency achieved:\n- 70% reduction in lead research time\n- 40% improvement in outreach response rates\nthrough automated lead data extraction and personalized messaging\n\nMarketing Material (Awareness Stage):\nDownload the comprehensive guide "AI-Driven Sales Automation: A Complete Playbook" for detailed insights on implementation strategies, tools, and real-world case studies.', additional_kwargs={}, response_metadata={'id': 'msg_01TPG8j7u6nEugrwY5NKekzw', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 2406, 'output_tokens': 172}}, id='run-d9b395ff-2ba4-4ddc-8612-664373760108-0', usage_metadata={'input_tokens': 2406, 'output_tokens': 172, 'total_tokens': 2578, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]
# final_email_output confidence='2' email_draft='Hi Pavan Kumar,\n\nThe AI Sales Research Agent offers several powerful features that can significantly enhance your sales processes:\n\n- **Automated LinkedIn/web scraping** for efficient lead data collection.\n- **Personalized first-touch email generation** to engage prospects effectively.\n- **Real-time CRM integration and updates** to keep your sales data current.\n- **Intent-based email categorization and follow-up automation** to streamline communication.\n- **Sales knowledge retrieval** from documents, CRM, and emails for informed decision-making.\n- **Automated sales reporting and presentation generation** to save time and improve accuracy.\n\nAdditionally, a real estate agency using this tool achieved a 70% reduction in lead research time and a 40% improvement in outreach response rates through automated lead data extraction and personalized messaging.\n\nFor more detailed insights on implementation strategies, tools, and real-world case studies, I recommend downloading our comprehensive guide, "AI-Driven Sales Automation: A Complete Playbook."\n\nBest regards,\n\n[Your Name]' hand_off_to_human='no'
# email draft final node Hi Pavan Kumar,
#
# The AI Sales Research Agent offers several powerful features that can significantly enhance your sales processes:
#
# - **Automated LinkedIn/web scraping** for efficient lead data collection.
# - **Personalized first-touch email generation** to engage prospects effectively.
# - **Real-time CRM integration and updates** to keep your sales data current.
# - **Intent-based email categorization and follow-up automation** to streamline communication.
# - **Sales knowledge retrieval** from documents, CRM, and emails for informed decision-making.
# - **Automated sales reporting and presentation generation** to save time and improve accuracy.
#
# Additionally, a real estate agency using this tool achieved a 70% reduction in lead research time and a 40% improvement in outreach response rates through automated lead data extraction and personalized messaging.
#
# For more detailed insights on implementation strategies, tools, and real-world case studies, I recommend downloading our comprehensive guide, "AI-Driven Sales Automation: A Complete Playbook."
#
# Best regards,
#
# [Your Name]

# %%
# for chunk in graph.stream({
    
#     "raw_email_body":"""<html><body> Hi Pavan Kumar,
# Hi Team,
# what is your pricing and lets setup a call?</body></html>""",
#     "company_domain_name": "innovizeai.com",
#     "sender_email_id":"pavan.kumar@innovizeai.com"
# }, subgraphs=True):
#     print(chunk)

# %%
response
# Out:
# {'sender_email_id': 'pavan.kumar@slack.com',
#  'raw_email_body': '<html><body> Hi Pavan Kumar,\n    what are the features of ai sales research agent?</body></html>',
#  'processed_email_body': ' Hi Pavan Kumar,\n    what are the features of ai sales research agent?',
#  'company_domain_name': 'innovizeai.com',
#  'sender_domain_name': 'slack.com',
#  'category': 'Enquiry',
#  'needs_response': 'Needs Response',
#  'confidence_score': 0.9,
#  'email_output': EmailOutput(confidence='2', email_draft='Hi Pavan Kumar,\n\nThe AI Sales Research Agent offers several powerful features that can significantly enhance your sales processes:\n\n- **Automated LinkedIn/web scraping** for efficient lead data collection.\n- **Personalized first-touch email generation** to engage prospects effectively.\n- **Real-time CRM integration and updates** to keep your sales data current.\n- **Intent-based email categorization and follow-up automation** to streamline communication.\n- **Sales knowledge retrieval** from documents, CRM, and emails for informed decision-making.\n- **Automated sales reporting and presentation generation** to save time and improve accuracy.\n\nAdditionally, a real estate agency using this tool achieved a 70% reduction in lead research time and a 40% improvement in outreach response rates through automated lead data extraction and personalized messaging.\n\nFor more detailed insights on implementation strategies, tools, and real-world case studies, I recommend downloading our comprehensive guide, "AI-Driven Sales Automation: A Complete Playbook."\n\nBest regards,\n\n[Your Name]', hand_off_to_human='no'),
#  'messages': [HumanMessage(content=' Hi Pavan Kumar,\n    what are the features of ai sales research agent?', additional_kwargs={}, response_metadata={}, id='e25faf4d-0bb9-4982-948f-09481ca56cb0'),
#   AIMessage(content='The AI Sales Research Agent offers several powerful capabilities:\n\nKey Features:\n- Automated LinkedIn/web scraping for lead data collection\n- Personalized first-touch email generation\n- Real-time CRM integration and updates\n- Intent-based email categorization and follow-up automation\n- Sales knowledge retrieval from documents, CRM, and emails\n- Automated sales reporting and presentation generation\n\nSuccess Story:\nA Real Estate Agency achieved:\n- 70% reduction in lead research time\n- 40% improvement in outreach response rates\nthrough automated lead data extraction and personalized messaging\n\nMarketing Material (Awareness Stage):\nDownload the comprehensive guide "AI-Driven Sales Automation: A Complete Playbook" for detailed insights on implementation strategies, tools, and real-world case studies.', additional_kwargs={}, response_metadata={'id': 'msg_01TPG8j7u6nEugrwY5NKekzw', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 2406, 'output_tokens': 172}}, id='run-d9b395ff-2ba4-4ddc-8612-664373760108-0', usage_metadata={'input_tokens': 2406, 'output_tokens': 172, 'total_tokens': 2578, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}
